# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('Social_Network_Ads.csv')

print(df.head())
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X = df[['Age', 'EstimatedSalary']]
y = df['Purchased']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0)

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
# Separate data
X0 = X[y == 0]
X1 = X[y == 1]

# Plot
plt.scatter(X0['Age'], X0['EstimatedSalary'], color='red', label='Not Purchased (0)')
plt.scatter(X1['Age'], X1['EstimatedSalary'], color='green', label='Purchased (1)')

plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.title("Logistics Regression")

plt.legend()   # 👈 IMPORTANT
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[65  3]
#  [ 8 24]]

# %%
TN, FP, FN, TP = cm.ravel()

accuracy = (TP + TN) / (TP + TN + FP + FN)
error_rate = 1 - accuracy
precision = TP / (TP + FP)
recall = TP / (TP + FN)

print("Accuracy:", accuracy)
print("Error Rate:", error_rate)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 0.89
# Error Rate: 0.10999999999999999
# Precision: 0.8888888888888888
# Recall: 0.75
